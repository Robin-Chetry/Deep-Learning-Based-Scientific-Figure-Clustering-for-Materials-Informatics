# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\rohit rawat\Desktop\iitr_internship\image_classification\data\balanced_subset.csv")

# %%
df.head()
# Out:
#                  image_id panel_suffix     visualization_category  \
# 0  ceramics_prod_img37464            B            Mechanical Test
# 1  ceramics_prod_img67212            A               Spectroscopy
# 2  ceramics_prod_img42745            B               Generic Plot
# 3  ceramics_prod_img33667            C           Electrochemistry
# 4        ni_alloy_img4271            B  Phase/Equilibrium Diagram
#
#   visualization_subtype                                         image_path  \
# 0   Stress-Strain Curve  /mnt/home2/home/subham_g1/subham_CMEG/material...
# 1         EELS Spectrum  /mnt/home2/home/subham_g1/subham_CMEG/material...
# 2             Histogram  /mnt/home2/home/subham_g1/subham_CMEG/material...
# 3          Nyquist Plot  /mnt/home2/home/subham_g1/subham_CMEG/material...
# 4       CALPHAD Diagram  /mnt/home2/home/subham_g1/subham_CMEG/material...
#
#                                              caption  \
# 0  Shear stress-strain curves for 3D-printed Ti6A...
# ...

# %%
df.shape
# Out:
# (24344, 7)

# %%
un=df["image_id"].unique()

# %%
print(len(un))
# Out:
# 18872

# %%
{image_id}_{panel_suffix}
